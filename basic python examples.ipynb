# %%
a = 100
b = 33
if a <b :
    print("b is greater than a")
elif a == b :
    print(" a is equal to b ")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
day = input('day name: ')
if (day == "sun"):
    print('Holiday')
elif (day == 'sat'):
    print('Halfday')
elif (day == 'fri'):
    print('sports day')

else:
    print('weekdays')
# Out:
# day name:  sun
# Holiday

# %%
num= int(input('number: '))
if (num % 2 == 0):
    print('even')
else:
    print('odd')
# Out:
# number:  12
# even

# %%
i = 1
while i <6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <6:
    print(i)
    if(i == 3):
        break
    i+=1
# Out:
# 1
# 2
# 3

# %%
i = 1
while i <6:
    i+=1
    
    if(i == 3):
        continue
    print(i)
# Out:
# 2
# 4
# 5
# 6

# %%
i = 0
while i<7:
    if(i == 4):
        i += 1
        continue
    print(i)
    if(i == 6):
        break
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 5
# 6

# %%
for i in range(0,5):
    # print(i)
    if(i == 3):
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
fruit = ['apple', 'pear','cherry','plum','orange','kiwi']

for i in fruit:
    if i == 'cherry':
        continue
    print(i)
    if i =='orange':
        break
# Out:
# apple
# pear
# plum
# orange

# %%
# how to draw pattern
for i in range(5,0,-1):
    print(i*'*')
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(5,0,-1):
    print(i*str(i))
# Out:
# 55555
# 4444
# 333
# 22
# 1
